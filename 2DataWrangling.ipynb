# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load and organize books data
books = pd.read_json('data_raw\goodreads_books_comics_graphic.json', lines=True)

# %%
books.head()
# Out:
#          isbn  text_reviews_count                            series  \
# 0                               1                                []
# 1  2205073346                   2                                []
# 2                               5  [246830, 362583, 362581, 623032]
# 3                               1                                []
# 4  0930289765                   6                 [266759, 1096220]
#
#   country_code language_code  \
# 0           US
# 1           US           fre
# 2           US           eng
# 3           US           eng
# 4           US         en-US
#
#                                      popular_shelves        asin is_ebook  \
# 0  [{'count': '228', 'name': 'to-read'}, {'count'...  B00NLXQ534     true
# 1  [{'count': '2', 'name': 'bd'}, {'count': '2', ...                false
# 2  [{'count': '493', 'name': 'to-read'}, {'count'...                false
# 3  [{'count': '222', 'name': 'to-read'}, {'count'...  B06XKGGSB7     true
# 4  [{'count': '20', 'name': 'to-read'}, {'count':...                false
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.12              ...
# 1            3.94              ...                 1
# 2            4.28              ...
# 3            4.05  B06XKGGSB7  ...
# 4            4.06              ...                11
#
#   publication_year                                                url  \
# 0                   https://www.goodreads.com/book/show/25742454-t...
# 1             2016  https://www.goodreads.com/book/show/30128855-c...
# 2             2012  https://www.goodreads.com/book/show/13571772-c...
# 3                   https://www.goodreads.com/book/show/35452242-b...
# 4             1997  https://www.goodreads.com/book/show/707611.Sup...
#
#                                            image_url   book_id ratings_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...  25742454             1
# 1  https://images.gr-assets.com/books/1462644346m...  30128855            16
# 2  https://images.gr-assets.com/books/1333287305m...  13571772            51
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  35452242             6
# 4  https://images.gr-assets.com/books/1307838888m...    707611            51
#
#     work_id                                              title  \
# 0  42749946                              The Switchblade Mamma
# 1  50558228                                            Cruelle
# 2    102217  Captain America: Winter Soldier (The Ultimate ...
# 3  54276229  Bounty Hunter 4/3: My Life in Combat from Mari...
# 4    693886                          Superman Archives, Vol. 2
#
#                                 title_without_series
# 0                              The Switchblade Mamma
# 1                                            Cruelle
# 2  Captain America: Winter Soldier (The Ultimate ...
# 3  Bounty Hunter 4/3: My Life in Combat from Mari...
# 4                          Superman Archives, Vol. 2
#
# [5 rows x 29 columns]

# %%
books.shape
# Out:
# (89411, 29)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89411 entries, 0 to 89410
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   isbn                  89411 non-null  object
#  1   text_reviews_count    89411 non-null  int64
#  2   series                89411 non-null  object
#  3   country_code          89411 non-null  object
#  4   language_code         89411 non-null  object
#  5   popular_shelves       89411 non-null  object
#  6   asin                  89411 non-null  object
#  7   is_ebook              89411 non-null  object
#  8   average_rating        89411 non-null  float64
#  9   kindle_asin           89411 non-null  object
#  10  similar_books         89411 non-null  object
#  11  description           89411 non-null  object
#  12  format                89411 non-null  object
#  13  link                  89411 non-null  object
#  14  authors               89411 non-null  object
#  15  publisher             89411 non-null  object
#  16  num_pages             89411 non-null  object
#  17  publication_day       89411 non-null  object
#  18  isbn13                89411 non-null  object
#  19  publication_month     89411 non-null  object
#  20  edition_information   89411 non-null  object
#  21  publication_year      89411 non-null  object
#  22  url                   89411 non-null  object
#  23  image_url             89411 non-null  object
#  24  book_id               89411 non-null  int64
#  25  ratings_count         89411 non-null  int64
#  26  work_id               89411 non-null  int64
#  27  title                 89411 non-null  object
#  28  title_without_series  89411 non-null  object
# dtypes: float64(1), int64(4), object(24)
# memory usage: 19.8+ MB

# %%
# What languages are there?
books.language_code.unique()
# Out:
# array(['', 'fre', 'eng', 'en-US', 'kor', 'jpn', 'spa', 'zho', 'ita',
#        'en-GB', 'nor', 'ind', 'cze', 'ben', 'swe', 'ger', 'nl', 'por',
#        'en-CA', 'gre', 'fin', 'rum', 'bos', 'msa', 'tur', 'per', 'pol',
#        'vie', 'hin', 'mul', 'dan', 'scr', 'tha', 'fil', 'rus', 'bul',
#        'srp', 'ara', 'nno', 'lav', 'heb', 'pes', 'cat', 'tgl', 'hun',
#        'nob', 'est', '--', 'ach', 'kat', 'ira', 'ukr', 'inh', 'slv',
#        'lit', 'sco', 'tel', 'slo', 'vai', 'eus', 'abk', 'ine', 'isl',
#        'glg', 'nld', 'wak', 'iku', 'fiu', 'aze', 'afr', 'dut', 'en'],
#       dtype=object)

# %%
# Keep only the books in english
books = books[books['language_code'].isin(['eng','en-US','en-GB','en-CA'])]

# Now that only english, what different countries are there?
print(books.country_code.unique())
# Out:
# ['US']

# %%
books.shape
# Out:
# (33925, 29)

# %% [markdown]
# <b>Notes on columns:</b>
# There are a bunch of columns that are unnecessary:
# * isbn/asin columns: these are forms of identification. will use book_id as identifier as that's what is used in columns like 'series' and 'smiliar_books'
# * publication month/day: seems like overkill to go down to this level of detail with publication date. publication year may be relevant...example if someone likes a lot of recent ones
# * link/url/image_url: don't need images
# * language_code: don't need this anymore
# * country_code: these are all "US" so no value in keeping

# %%
books = books.drop(['isbn','language_code','asin','kindle_asin','work_id','image_url','link',
                    'url','isbn13', 'publication_month','publication_day','country_code'],axis=1)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33925 entries, 2 to 89410
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   text_reviews_count    33925 non-null  int64
#  1   series                33925 non-null  object
#  2   popular_shelves       33925 non-null  object
#  3   is_ebook              33925 non-null  object
#  4   average_rating        33925 non-null  float64
#  5   similar_books         33925 non-null  object
#  6   description           33925 non-null  object
#  7   format                33925 non-null  object
#  8   authors               33925 non-null  object
#  9   publisher             33925 non-null  object
#  10  num_pages             33925 non-null  object
#  11  edition_information   33925 non-null  object
#  12  publication_year      33925 non-null  object
#  13  book_id               33925 non-null  int64
#  14  ratings_count         33925 non-null  int64
#  15  title                 33925 non-null  object
#  16  title_without_series  33925 non-null  object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 4.7+ MB

# %% [markdown]
# <b>Columns for further exploration:</b>
# For these columns it isn't exactly clear whether they're helpful to our purposes or not. Need to get a better understanding of them:
# * 'book_id' seems like it would make a good index
# * 'publisher' could this be relevant?
# * 'edition_information' could this be relevant?
# * 'is_ebook' seems like it could be combined easily with 'format'
# * check 'title' and 'title_without_series' - could these be broken into 'title' and 'series'? if so, is series irrelevent given there is a separate 'series' column that list other books in the series?
# * 'authors'needs further exploration
# * 'series' not quite sure how this ties to other books
# * 'popular_shelves' needs further exploration

# %%
# set 'book_id' as index
books.set_index('book_id',inplace=True)

# %%
# publisher column
print(books.publisher.unique())
print(books.publisher.value_counts())
# Out:
# ['Hachette Partworks Ltd.' '' 'DC Comics' ...
#  'Henry Holt and Company, Inc.' 'Crabtree Publishing Company' 'Vintage']
#                           7373
# Marvel                    3017
# DC Comics                 2984
# VIZ Media LLC             1942
# Image Comics              1750
#                           ...
# Open Court                   1
# Pathfinder Press, Inc.       1
# Egmont/Methuen               1
# Rebellion (2000AD)           1
# Amistad                      1
# Name: publisher, Length: 2849, dtype: int64

# %% [markdown]
# Publisher seems like it could potentially be relevant at first glance. If someone likes a lot of Marvel comics, for example, they would likely be more inclined to like another Marvel comic in the future.
#
# But this information is probably encapsulated better at the title level - i.e. the fact that someone likes a Marvel Captain America comic could be gathered in more detail by the title "Captain America" rather than the publisher "Marvel"

# %%
books.drop('publisher',axis=1, inplace=True)

# %%
# edition_information
books.edition_information.value_counts()
# Out:
#                          30589
# Trade                      487
# Premiere                   218
# First                      180
# Deluxe Edition             173
#                          ...
# 10 issues                    1
# The New 52                   1
# Helen Exley Giftbooks        1
# ThinkGeek Cover              1
# Media-Tie                    1
# Name: edition_information, Length: 714, dtype: int64

# %% [markdown]
# 'edition_information' is mostly blank. The remainder are frequently one-offs as well.

# %%
books.drop('edition_information',axis=1, inplace=True)

# %%
# Examine 'is_ebook' and 'format' - they're giving the same information. 
# Is that information necessary to keep? If so, how can we combine?
print(books.is_ebook.value_counts())
print(books.format.value_counts())
# Out:
# false    27960
# true      5965
# Name: is_ebook, dtype: int64
# Paperback                                17789
#                                           8370
# Hardcover                                 4834
# ebook                                     1191
# Kindle Edition                             650
#                                          ...
# Leather Bound                                1
# issue                                        1
# Horror Comic                                 1
# A4 Softcover                                 1
# The Walking Dead - Single Issues #134        1
# Name: format, Length: 147, dtype: int64

# %%
books.format.unique()
# Out:
# array(['Hardcover', '', 'Paperback', 'Kindle Edition', 'ebook',
#        'Comic Book', 'Comic', 'Digital Comic', 'Unknown Binding',
#        'Mass Market Paperback', 'Nook', 'Library Binding', 'Webtoon',
#        'Comics', 'Book', 'Audible Audio', 'Hardcover with dust jacket',
#        'Custom Handmade Binding', 'Spiral-bound', 'free manga scanlation',
#        'Trade Paperback', 'FC', 'Slipcased Hardcover', 'Online',
#        'webtoon', 'Board book', 'Paperback Manga', 'Unbound',
#        'Single Issue', 'comic', 'paperback', 'One-Shot Comic',
#        'Graphic Novels', 'Comixology Edition', 'Digital', 'Comic book',
#        'The Walking Dead - Single Issues #146', 'Over-sized Soft-cover',
#        'Audiobook', 'Paperback - Manga', 'Issue', 'Flexiback', 'Audio CD',
#        'The Walking Dead - Single Issues #135', 'Graphic Novel',
#        'Webcomic/Manhua', 'Print Comic', 'Online Comic', 'PDF',
#        'Magazine', 'CD-ROM', 'staple-bound', 'Webcomic', 'Prestige',
#        'Leather Bound', 'The Walking Dead - Single Issues #144',
#        'Softcover', 'Trade Paperback Graphic Novel', 'Tabloid',
#        'Board Book', 'digital', 'Slipcased hardcover (1-3)',
#        'trade paperback',
#        'Hand-bound Art Portfolio w/7&quot; Vinyl Record',
#        'Kindle Graphic Novel', 'Graphic', 'saddle stitch', 'Trade Cloth',
#        'Manga Online', 'Comic Book Issue', 'Digital comic', 'hardcover',
#        'Digital Comic Book', 'comic book', 'Box Set',
#        'The Walking Dead - Single Issues #143', 'Graphic novel',
#        'PDF DIGITAL EDITION', 'mini-paperback', 'online comic',
#        'Cardstock', 'Saddle-stitched',
#        'The Walking Dead - Single Issues #137', 'Soft Cover',
#        'Serial Comic', '13&quot; by 10&quot; softcover',
#        'Single Issue Comicbook', 'A4 Softcover', 'comic books',
#        'The Walking Dead - Single Issues #134', 'Online Comic - Webcomic',
#        'Comixology', 'collection', 'TPB', 'Graphic Anthology',
#        'Comixology Guided View', 'Pamphlet', "artist's book",
#        'graphic novel', 'Broche', 'Prestige One-Shot',
#        'Slipcase Hardcover', 'Hardcover Comic', 'Web Comic/ Manhua',
#        'Paperback graphic novel', 'Saddle stitched', 'online Comic Book',
#        'Horror Comic', 'Comicbook', 'Kindle Edition, with panel zoom',
#        'Yaoi', 'The Walking Dead - Single Issues #141', 'Grapic Novel',
#        'Deluxe Softcover', 'The Walking Dead - Single Issues #136',
#        'Trade Paperback - hardback',
#        'The Walking Dead - Single Issues #140',
#        'The Walking Dead - Single Issues #139',
#        'Oversized Slipcased Hardcover', 'zine', 'Comic Trade Paperback',
#        'Zine', 'Manga', 'Novelty Book', 'Motion Book', 'issue',
#        'Squarebound', 'Webcomics', 'web', 'Single issue comic',
#        'deluxe comic', 'The Walking Dead - Single Issues #142',
#        'Graphic Novel Paperback', 'Online Manga Series', 'GRAPHIC NOVEL',
#        'Web Comic', 'Graphic novel issue', 'Online eBook',
#        'online graphic novel - complete', 'Boxed Set', 'Audio',
#        'The Walking Dead - Single Issues #138', 'manga',
#        '(The Walking Dead - Single Issues #132)',
#        'Graphic Novel Trade Hardcover', 'GraphicAudio', 'manhwa'],
#       dtype=object)

# %%
books.drop(['is_ebook','format'], axis=1, inplace=True)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33925 entries, 13571772 to 23363286
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   text_reviews_count    33925 non-null  int64
#  1   series                33925 non-null  object
#  2   popular_shelves       33925 non-null  object
#  3   average_rating        33925 non-null  float64
#  4   similar_books         33925 non-null  object
#  5   description           33925 non-null  object
#  6   authors               33925 non-null  object
#  7   num_pages             33925 non-null  object
#  8   publication_year      33925 non-null  object
#  9   ratings_count         33925 non-null  int64
#  10  title                 33925 non-null  object
#  11  title_without_series  33925 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# <b>Title columns:</b>
# What's the difference between title and title with series? There is also a separate series column. Does that encapsulate any add'l info in the title with series column?

# %%
books.head()
# Out:
#           text_reviews_count                            series  \
# book_id
# 13571772                   5  [246830, 362583, 362581, 623032]
# 35452242                   1                                []
# 707611                     6                 [266759, 1096220]
# 27036536                   9                          [834955]
# 11827783                  26                          [774390]
#
#                                             popular_shelves  average_rating  \
# book_id
# 13571772  [{'count': '493', 'name': 'to-read'}, {'count'...            4.28
# 35452242  [{'count': '222', 'name': 'to-read'}, {'count'...            4.05
# 707611    [{'count': '20', 'name': 'to-read'}, {'count':...            4.06
# 27036536  [{'count': '47', 'name': 'to-read'}, {'count':...            4.15
# 11827783  [{'count': '104', 'name': 'to-read'}, {'count'...            3.16
#
#                                               similar_books  \
# book_id
# 13571772  [13590139, 105963, 207585, 10503130, 4645370, ...
# 35452242                                                 []
# 707611                                                   []
# 27036536                                                 []
# 11827783  [6651573, 8835785, 15060759, 9466897, 8423991,...
#
#                                                 description  \
# book_id
# 13571772  The questions plaguing Captain America's dream...
# 35452242  The fight for Jason Delgado's life and soul be...
# 707611    These are the stories that catapulted Superman...
# 27036536  PRODUCT DESCRIPTION: The first new volume of G...
# 11827783  Sir Arthur Conan Doyle's dauntless detective r...
#
#                                                     authors num_pages  \
# book_id
# 13571772               [{'author_id': '37450', 'role': ''}]       146
# 35452242  [{'author_id': '16209952', 'role': ''}, {'auth...
# 707611    [{'author_id': '81563', 'role': ''}, {'author_...       272
# 27036536  [{'author_id': '14965', 'role': ''}, {'author_...       224
# 11827783  [{'author_id': '61231', 'role': ''}, {'author_...       144
#
#          publication_year  ratings_count  \
# book_id
# 13571772             2012             51
# 35452242                               6
# 707611               1997             51
# 27036536             2016             39
# 11827783             2011            114
#
#                                                       title  \
# book_id
# 13571772  Captain America: Winter Soldier (The Ultimate ...
# 35452242  Bounty Hunter 4/3: My Life in Combat from Mari...
# 707611                            Superman Archives, Vol. 2
# 27036536                              War Stories, Volume 3
# 11827783                          Sherlock Holmes: Year One
#
#                                        title_without_series
# book_id
# 13571772  Captain America: Winter Soldier (The Ultimate ...
# 35452242  Bounty Hunter 4/3: My Life in Combat from Mari...
# 707611                            Superman Archives, Vol. 2
# 27036536                              War Stories, Volume 3
# 11827783                          Sherlock Holmes: Year One

# %% [markdown]
# Based on the first 5 rows they seem identical. Let's look at a bigger sample.

# %%
books.sample(25)
# Out:
#           text_reviews_count                      series  \
# book_id
# 25529990                   4                    [872164]
# 28109898                  15           [876409, 1136359]
# 22878114                  18                    [768017]
# 28226421                   2                    [953603]
# 25052119                  11                          []
# 25489038                  28                   [1106249]
# 22609194                   5                    [735762]
# 10613188                   3           [729522, 1132257]
# 543153                     3                    [953195]
# 514829                    13                          []
# 17342205                   4                    [783976]
# 105944                    27                    [257644]
# 8444997                  106                    [320146]
# 7959226                   15                    [176727]
# 7933628                   13                    [186322]
# 9659886                   12                    [251080]
# 6867945                    9                    [293096]
# 25132962                   2                          []
# 30763                      1                    [332966]
# 397258                     9                    [198365]
# 26159538                   2                   [1120882]
# 13175917                  70                    [364753]
# 32803017                   1                    [484141]
# 17824752                 498  [990883, 1101516, 1130803]
# 57899                     16                    [277587]
#
#                                             popular_shelves  average_rating  \
# book_id
# 25529990  [{'count': '7', 'name': 'comics'}, {'count': '...            3.52
# 28109898  [{'count': '49', 'name': 'to-read'}, {'count':...            3.36
# 22878114  [{'count': '442', 'name': 'to-read'}, {'count'...            4.09
# 28226421  [{'count': '66', 'name': 'to-read'}, {'count':...            4.27
# 25052119  [{'count': '14', 'name': 'to-read'}, {'count':...            3.92
# 25489038  [{'count': '62', 'name': 'to-read'}, {'count':...            3.80
# 22609194  [{'count': '27', 'name': 'manga'}, {'count': '...            3.96
# 10613188  [{'count': '30', 'name': 'to-read'}, {'count':...            3.31
# 543153    [{'count': '12', 'name': 'to-read'}, {'count':...            3.34
# 514829    [{'count': '26', 'name': 'to-read'}, {'count':...            2.97
# 17342205  [{'count': '17', 'name': 'to-read'}, {'count':...            4.26
# 105944    [{'count': '131', 'name': 'to-read'}, {'count'...            4.32
# 8444997   [{'count': '1617', 'name': 'to-read'}, {'count...            3.99
# 7959226   [{'count': '43', 'name': 'to-read'}, {'count':...            4.08
# 7933628   [{'count': '116', 'name': 'to-read'}, {'count'...            4.31
# 9659886   [{'count': '82', 'name': 'manga'}, {'count': '...            4.33
# 6867945   [{'count': '125', 'name': 'manga'}, {'count': ...            4.15
# 25132962  [{'count': '2', 'name': 'to-read'}, {'count': ...            4.33
# 30763     [{'count': '49', 'name': 'manga'}, {'count': '...            3.44
# 397258    [{'count': '47', 'name': 'to-read'}, {'count':...            3.46
# 26159538  [{'count': '4', 'name': 'to-read'}, {'count': ...            3.78
# 13175917  [{'count': '217', 'name': 'to-read'}, {'count'...            4.12
# 32803017  [{'count': '1368', 'name': 'to-read'}, {'count...            4.29
# 17824752  [{'count': '2642', 'name': 'to-read'}, {'count...            4.11
# 57899     [{'count': '200', 'name': 'manga'}, {'count': ...            4.21
#
#                                               similar_books  \
# book_id
# 25529990                                                 []
# 28109898                                                 []
# 22878114  [25893817, 20444960, 25233408, 24357289, 17409...
# 28226421                                                 []
# 25052119                                                 []
# 25489038                                                 []
# 22609194                                                 []
# 10613188                                                 []
# 543153                                                   []
# 514829                                                   []
# 17342205                                                 []
# 105944    [6420788, 139996, 52368, 418107, 7619091, 1727...
# 8444997   [10390076, 7775819, 7326782, 3430761, 717201, ...
# 7959226   [354223, 93317, 678280, 20256, 678273, 343312,...
# 7933628      [475025, 15010610, 9282790, 10054014, 7265137]
# 9659886             [11017065, 10954336, 16049255, 7932994]
# 6867945   [9724683, 3259434, 12738757, 7326813, 1677319,...
# 25132962                                                 []
# 30763                                                    []
# 397258                                                   []
# 26159538                                                 []
# 13175917  [15894969, 12481074, 9866153, 16121414, 144896...
# 32803017  [16074588, 17182539, 17348705, 20759686, 16074...
# 17824752  [331201, 17182373, 20898015, 17277800, 3905051...
# 57899                   [1201650, 555420, 248868, 11489897]
#
#                                                 description  \
# book_id
# 25529990  STARRING HEROES FROM ZERO HOUR! It's a family ...
# 28109898  It's a scary-good new direction for the Emeral...
# 22878114  It's a quirky new take on the magical girl gen...
# 28226421  Every ninety years, twelve gods incarnate as h...
# 25052119  A psychopath escapes from an asylum and become...
# 25489038  A grumpy cloud upsets his friend Sunny and mus...
# 22609194  Superpowered humans known as NEXT appeared in ...
# 10613188  The Sentinel of Liberty smashes into action! I...
# 543153
# 514829    Everybody knows the story of Spider-Man... but...
# 17342205  Recipes for the Dead is a story about a shy gi...
# 105944    Daredevil is simultaneously faced with murder ...
# 8444997   Tsubasa thinks that her pretty and popular twi...
# 7959226   Following his 20th anniversary hit, Dilbert 2....
# 7933628   The milestone 50th GARFIELD compilation book--...
# 9659886   Drama with a light touch, Cross Game will chan...
# 6867945   The Hidden World seems less and less hidden as...
# 25132962
# 30763     As the Revolutionary Army prepares to defend t...
# 397258    TURNING JAPANESEIt's the end of Ellie's senior...
# 26159538
# 13175917  Traveling by secret railroad, Becky and Drake ...
# 32803017  It's ADVENTURE TIME! Join Finn the Human, Jake...
# 17824752  Legacy isn't a dirty word...but it's an irrele...
# 57899     Of the original 42 students forced to kill or ...
#
#                                                     authors num_pages  \
# book_id
# 25529990  [{'author_id': '233071', 'role': ''}, {'author...
# 28109898  [{'author_id': '215907', 'role': 'Writer'}, {'...       168
# 22878114  [{'author_id': '6887313', 'role': ''}, {'autho...        22
# 28226421  [{'author_id': '439887', 'role': ''}, {'author...       512
# 25052119  [{'author_id': '8284860', 'role': ''}, {'autho...        90
# 25489038  [{'author_id': '137561', 'role': ''}, {'author...        22
# 22609194  [{'author_id': '103319', 'role': ''}, {'author...
# 10613188  [{'author_id': '102836', 'role': 'Text'}, {'au...        96
# 543153                [{'author_id': '358991', 'role': ''}]
# 514829                [{'author_id': '286016', 'role': ''}]       104
# 17342205  [{'author_id': '6926295', 'role': ''}, {'autho...        20
# 105944    [{'author_id': '12424', 'role': 'Text'}, {'aut...       120
# 8444997   [{'author_id': '165682', 'role': ''}, {'author...       208
# 7959226                 [{'author_id': '5282', 'role': ''}]       128
# 7933628                [{'author_id': '56083', 'role': ''}]        96
# 9659886   [{'author_id': '366315', 'role': ''}, {'author...       370
# 6867945   [{'author_id': '2339572', 'role': ''}, {'autho...       178
# 25132962  [{'author_id': '15091', 'role': ''}, {'author_...        25
# 30763                  [{'author_id': '17262', 'role': ''}]
# 397258    [{'author_id': '621', 'role': ''}, {'author_id...       128
# 26159538  [{'author_id': '45103', 'role': ''}, {'author_...
# 13175917  [{'author_id': '591619', 'role': ''}, {'author...       151
# 32803017  [{'author_id': '45763', 'role': ''}, {'author_...       121
# 17824752  [{'author_id': '439887', 'role': 'Writer'}, {'...       120
# 57899     [{'author_id': '32595', 'role': ''}, {'author_...
#
#          publication_year  ratings_count  \
# book_id
# 25529990                              25
# 28109898             2016            117
# 22878114             2014            247
# 28226421                              45
# 25052119                              22
# 25489038             2016            125
# 22609194                              69
# 10613188             2011             15
# 543153                                32
# 514829               2005             93
# 17342205             2010             19
# 105944               2006            821
# 8444997              2010           3275
# 7959226              2010            153
# 7933628              2010            232
# 9659886              2011            319
# 6867945              2010            386
# 25132962             2004              3
# 30763                                106
# 397258               2006             63
# 26159538                               7
# 13175917             2012            945
# 32803017             2013              4
# 17824752             2013           8095
# 57899                                978
#
#                                                       title  \
# book_id
# 25529990                        Convergence: Green Arrow #2
# 28109898              Green Arrow, Volume 8: The Nightbirds
# 22878114                                Bee and Puppycat #1
# 28226421                  The Wicked + The Divine Vol 1,2,3
# 25052119  Ichabod Jones: Monster Hunter: A psychopath's ...
# 25489038                                         I'm Grumpy
# 22609194                            TIGER & BUNNY GN VOL 06
# 10613188        Marvel Adventures Avengers: Captain America
# 543153                  Hellraiser Nightbreed Jihad: Book 1
# 514829                                    Spider-Man: India
# 17342205                      Recipes for the Dead: Issue 1
# 105944                          Daredevil, Vol. 7: Hardcore
# 8444997                          Arisa, Vol. 01 (Arisa, #1)
# 7959226                 I'm Tempted to Stop Acting Randomly
# 7933628            Garfield Potbelly of Gold (Garfield #50)
# 9659886                     Cross Game 3 (Cross Game, #6–7)
# 6867945             Nabari No Ou, Vol. 3 (Nabari No Ou, #3)
# 25132962                      X-Men: Excalibur III issue #6
# 30763                      The Vision of Escaflowne, Vol. 6
# 397258          Turning Japanese (Degrassi Extra Credit #1)
# 26159538                                    Red Sonja #1973
# 13175917   The Sixth Gun, Vol. 3: Bound (The Sixth Gun, #3)
# 32803017                             Adventure Time, Vol. 1
# 17824752        Young Avengers, Volume 1: Style > Substance
# 57899           Battle Royale, Vol. 13 (Battle Royale, #13)
#
#                                        title_without_series
# book_id
# 25529990                        Convergence: Green Arrow #2
# 28109898              Green Arrow, Volume 8: The Nightbirds
# 22878114                                Bee and Puppycat #1
# 28226421                  The Wicked + The Divine Vol 1,2,3
# 25052119  Ichabod Jones: Monster Hunter: A psychopath's ...
# 25489038                                         I'm Grumpy
# 22609194                            TIGER & BUNNY GN VOL 06
# 10613188        Marvel Adventures Avengers: Captain America
# 543153                  Hellraiser Nightbreed Jihad: Book 1
# 514829                                    Spider-Man: India
# 17342205                      Recipes for the Dead: Issue 1
# 105944                          Daredevil, Vol. 7: Hardcore
# 8444997                          Arisa, Vol. 01 (Arisa, #1)
# 7959226                 I'm Tempted to Stop Acting Randomly
# 7933628            Garfield Potbelly of Gold (Garfield #50)
# 9659886                     Cross Game 3 (Cross Game, #6–7)
# 6867945             Nabari No Ou, Vol. 3 (Nabari No Ou, #3)
# 25132962                      X-Men: Excalibur III issue #6
# 30763                      The Vision of Escaflowne, Vol. 6
# 397258          Turning Japanese (Degrassi Extra Credit #1)
# 26159538                                    Red Sonja #1973
# 13175917   The Sixth Gun, Vol. 3: Bound (The Sixth Gun, #3)
# 32803017                             Adventure Time, Vol. 1
# 17824752        Young Avengers, Volume 1: Style > Substance
# 57899           Battle Royale, Vol. 13 (Battle Royale, #13)

# %%
books.title.value_counts()
# Out:
# Watchmen                                 11
# Batman: The Dark Knight Returns           9
# Batman: Year One                          8
# Preludes & Nocturnes (The Sandman #1)     7
# Kingdom Come                              7
#                                          ..
# Captain America: Prisoner of War          1
# Batman Detective Comics #43               1
# Desire: Dangerous Feelings                1
# Sonic Select Book 10                      1
# Psychic Detective Yakumo Vol. 1           1
# Name: title, Length: 31523, dtype: int64

# %%
books.title_without_series.value_counts()
# Out:
# Watchmen                                 11
# Batman: The Dark Knight Returns           9
# Batman: Year One                          8
# Preludes & Nocturnes (The Sandman #1)     7
# Kingdom Come                              7
#                                          ..
# Captain America: Prisoner of War          1
# Batman Detective Comics #43               1
# Desire: Dangerous Feelings                1
# Sonic Select Book 10                      1
# Psychic Detective Yakumo Vol. 1           1
# Name: title_without_series, Length: 31523, dtype: int64

# %%
# These seem basically identical. Will drop the title_without_series.
books.drop('title_without_series',inplace=True,axis=1)

# %% [markdown]
# <b>Authors</b>
# It looks like authors column is a list of dictionaries where each dictionary in the list contains author_id and role for each of the authors on the book.

# %%
books.head()
# Out:
#           text_reviews_count                            series  \
# book_id
# 13571772                   5  [246830, 362583, 362581, 623032]
# 35452242                   1                                []
# 707611                     6                 [266759, 1096220]
# 27036536                   9                          [834955]
# 11827783                  26                          [774390]
#
#                                             popular_shelves  average_rating  \
# book_id
# 13571772  [{'count': '493', 'name': 'to-read'}, {'count'...            4.28
# 35452242  [{'count': '222', 'name': 'to-read'}, {'count'...            4.05
# 707611    [{'count': '20', 'name': 'to-read'}, {'count':...            4.06
# 27036536  [{'count': '47', 'name': 'to-read'}, {'count':...            4.15
# 11827783  [{'count': '104', 'name': 'to-read'}, {'count'...            3.16
#
#                                               similar_books  \
# book_id
# 13571772  [13590139, 105963, 207585, 10503130, 4645370, ...
# 35452242                                                 []
# 707611                                                   []
# 27036536                                                 []
# 11827783  [6651573, 8835785, 15060759, 9466897, 8423991,...
#
#                                                 description  \
# book_id
# 13571772  The questions plaguing Captain America's dream...
# 35452242  The fight for Jason Delgado's life and soul be...
# 707611    These are the stories that catapulted Superman...
# 27036536  PRODUCT DESCRIPTION: The first new volume of G...
# 11827783  Sir Arthur Conan Doyle's dauntless detective r...
#
#                                                     authors num_pages  \
# book_id
# 13571772               [{'author_id': '37450', 'role': ''}]       146
# 35452242  [{'author_id': '16209952', 'role': ''}, {'auth...
# 707611    [{'author_id': '81563', 'role': ''}, {'author_...       272
# 27036536  [{'author_id': '14965', 'role': ''}, {'author_...       224
# 11827783  [{'author_id': '61231', 'role': ''}, {'author_...       144
#
#          publication_year  ratings_count  \
# book_id
# 13571772             2012             51
# 35452242                               6
# 707611               1997             51
# 27036536             2016             39
# 11827783             2011            114
#
#                                                       title
# book_id
# 13571772  Captain America: Winter Soldier (The Ultimate ...
# 35452242  Bounty Hunter 4/3: My Life in Combat from Mari...
# 707611                            Superman Archives, Vol. 2
# 27036536                              War Stories, Volume 3
# 11827783                          Sherlock Holmes: Year One

# %% [markdown]
# My goal is to extract the authors and roles for the authors from each row. I can see if role is relevant...it looks like it's blank based on the head. If so, can discard that information and just keep a list of the authors.

# %%
# get a list of all the authors
authors = [[x.get('author_id') for x in d] for d in books.authors]

# %%
# Check that it worked
print(authors[:10])
print(len(authors))
print(len(books.authors))
# Out:
# [['37450'], ['16209952', '853385'], ['81563', '89537'], ['14965', '3188368', '131836', '7507599'], ['61231', '4980321'], ['294649'], ['311098'], ['12772', '12771'], ['130617'], ['5340891', '5340892', '7224524']]
# 33925
# 33925

# %%
# do the same for all the roles
roles = [[x.get('role') for x in d] for d in books.authors]

# %%
print(len(roles))
print(roles[:10])
# Out:
# 33925
# [[''], ['', ''], ['', 'Illustrator'], ['', 'Illustrations', 'Illustrations', ''], ['', 'Illustrator'], [''], [''], ['', 'Illustrator'], [''], ['', 'Illustrator', 'doujinshi circle']]

# %%
r = pd.Series(roles)
r.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                                                                                                                                                  10639
# [, Illustrator]                                                                                                                                                      3874
# [, ]                                                                                                                                                                 2121
# [, Illustrator, Illustrator]                                                                                                                                         1426
# [, Translator]                                                                                                                                                        725
#                                                                                                                                                                     ...
# [, Penciller, Illustrator, Inker, Illustrator, Variant Cover, Variant Cover]                                                                                            1
# [Writer, Illustrator, Illustrator, Illustrator, Colorist]                                                                                                               1
# [, , Penciler, Penciler, Inker, Inker]                                                                                                                                  1
# [, Illustrator, , Illustrator, , Illustrator, , Illustrator, Illustrator]                                                                                               1
# [, contributor, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, illustrator, ]        1
# Length: 4054, dtype: int64

# %% [markdown]
# The roles information seems largely missing and/or irrelevant, so will leave that out. But authors could potentially add value.

# %%
books['authors'] = authors

# %%
books.head()
# Out:
#           text_reviews_count                            series  \
# book_id
# 13571772                   5  [246830, 362583, 362581, 623032]
# 35452242                   1                                []
# 707611                     6                 [266759, 1096220]
# 27036536                   9                          [834955]
# 11827783                  26                          [774390]
#
#                                             popular_shelves  average_rating  \
# book_id
# 13571772  [{'count': '493', 'name': 'to-read'}, {'count'...            4.28
# 35452242  [{'count': '222', 'name': 'to-read'}, {'count'...            4.05
# 707611    [{'count': '20', 'name': 'to-read'}, {'count':...            4.06
# 27036536  [{'count': '47', 'name': 'to-read'}, {'count':...            4.15
# 11827783  [{'count': '104', 'name': 'to-read'}, {'count'...            3.16
#
#                                               similar_books  \
# book_id
# 13571772  [13590139, 105963, 207585, 10503130, 4645370, ...
# 35452242                                                 []
# 707611                                                   []
# 27036536                                                 []
# 11827783  [6651573, 8835785, 15060759, 9466897, 8423991,...
#
#                                                 description  \
# book_id
# 13571772  The questions plaguing Captain America's dream...
# 35452242  The fight for Jason Delgado's life and soul be...
# 707611    These are the stories that catapulted Superman...
# 27036536  PRODUCT DESCRIPTION: The first new volume of G...
# 11827783  Sir Arthur Conan Doyle's dauntless detective r...
#
#                                     authors num_pages publication_year  \
# book_id
# 13571772                            [37450]       146             2012
# 35452242                 [16209952, 853385]
# 707611                       [81563, 89537]       272             1997
# 27036536  [14965, 3188368, 131836, 7507599]       224             2016
# 11827783                   [61231, 4980321]       144             2011
#
#           ratings_count                                              title
# book_id
# 13571772             51  Captain America: Winter Soldier (The Ultimate ...
# 35452242              6  Bounty Hunter 4/3: My Life in Combat from Mari...
# 707611               51                          Superman Archives, Vol. 2
# 27036536             39                              War Stories, Volume 3
# 11827783            114                          Sherlock Holmes: Year One

# %% [markdown]
# <b>Series column:</b> It seems like this is a list of other books in the same series as the book at hand. Want to confirm.
#
# After exploring documentation from the studies using this data. It appears these refer to a separate "series" dataset, not other books in the same series.

# %%
# confirm that the series numbers don't tie
# here is a book
books.loc[707611,:]
# Out:
# text_reviews_count                                                    6
# series                                                [266759, 1096220]
# popular_shelves       [{'count': '20', 'name': 'to-read'}, {'count':...
# average_rating                                                     4.06
# similar_books                                                        []
# description           These are the stories that catapulted Superman...
# authors                                                  [81563, 89537]
# num_pages                                                           272
# publication_year                                                   1997
# ratings_count                                                        51
# title                                         Superman Archives, Vol. 2
# Name: 707611, dtype: object

# %%
# if we try to locate the book_id for one of the "series" records above, it doesn't exist
books.loc[266759]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 266759
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-63434234a056> in <module>
# ----> 1 books.loc[266759]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 266759

# %% [markdown]
# So it doesn't appear series is a list of other books in the same series. After reviewing the online docs from the study that gathered this data, it looks like series refers to a separate series_id in a different table of data. This isn't relevant to our current purposes.

# %%
books.drop('series',inplace=True, axis=1)

# %% [markdown]
# <b>Popular Shelves:</b>
# This seems like it will be incorporated from the combining with the reviews dataset.

# %%
books.drop('popular_shelves', inplace=True, axis=1)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33925 entries, 13571772 to 23363286
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   text_reviews_count  33925 non-null  int64
#  1   average_rating      33925 non-null  float64
#  2   similar_books       33925 non-null  object
#  3   description         33925 non-null  object
#  4   authors             33925 non-null  object
#  5   num_pages           33925 non-null  object
#  6   publication_year    33925 non-null  object
#  7   ratings_count       33925 non-null  int64
#  8   title               33925 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 3.8+ MB

# %%
books.to_csv('data/books_comics_cleaned.csv')

# %%
# Load and clean up reviews data
reviews = pd.read_json('data_raw\goodreads_reviews_comics_graphic.json', lines=True)

# %%
reviews.head()
# Out:
#                             user_id   book_id  \
# 0  dc3763cdb9b2cae805882878eebb6a32  18471619
# 1  bafc2d50014200cda7cb2b6acd60cd73   6315584
# 2  bafc2d50014200cda7cb2b6acd60cd73  29847729
# 3  bafc2d50014200cda7cb2b6acd60cd73  18454118
# 4  bafc2d50014200cda7cb2b6acd60cd73   2239435
#
#                           review_id  rating  \
# 0  66b2ba840f9bd36d6d27f46136fe4772       3
# 1  72f1229aba5a88f9e72f0dcdc007dd22       4
# 2  a75309355f8662caaa5e2c92ab693d3f       4
# 3  c3cc5a3e1d6b6c9cf1c044f306c8e752       5
# 4  cc444be37ab0a42bfb4dd818cb5edd10       4
#
#                                          review_text  \
# 0  Sherlock Holmes and the Vampires of London \n ...
# 1  I've never really liked Spider-Man. I am, howe...
# 2  A very quick introduction, this is coming out ...
# 3  I've been waiting so long for this. I first st...
# 4  The only thing more entertaining than this boo...
#
#                        date_added                    date_updated  \
# 0  Thu Dec 05 10:44:25 -0800 2013  Thu Dec 05 10:45:15 -0800 2013
# 1  Wed Aug 10 06:06:48 -0700 2016  Fri Aug 12 08:49:54 -0700 2016
# 2  Thu Apr 21 07:44:00 -0700 2016  Thu Apr 21 07:59:28 -0700 2016
# 3  Mon Mar 03 17:45:56 -0800 2014  Mon Mar 03 17:54:11 -0800 2014
# 4  Wed Apr 03 12:37:48 -0700 2013  Wed Apr 03 13:03:36 -0700 2013
#
#                           read_at                      started_at  n_votes  \
# 0  Tue Nov 05 00:00:00 -0800 2013                                        0
# 1  Fri Aug 12 08:49:54 -0700 2016  Wed Aug 10 00:00:00 -0700 2016        0
# 2  Thu Apr 21 07:59:28 -0700 2016  Thu Apr 21 00:00:00 -0700 2016        0
# 3  Sat Mar 01 00:00:00 -0800 2014  Sat Mar 01 00:00:00 -0800 2014        1
# 4  Wed Apr 03 13:03:36 -0700 2013                                        0
#
#    n_comments
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542338 entries, 0 to 542337
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       542338 non-null  object
#  1   book_id       542338 non-null  int64
#  2   review_id     542338 non-null  object
#  3   rating        542338 non-null  int64
#  4   review_text   542338 non-null  object
#  5   date_added    542338 non-null  object
#  6   date_updated  542338 non-null  object
#  7   read_at       542338 non-null  object
#  8   started_at    542338 non-null  object
#  9   n_votes       542338 non-null  int64
#  10  n_comments    542338 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 45.5+ MB

# %%
reviews.drop(['date_updated','read_at','started_at','n_votes','n_comments'], inplace=True, axis=1)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542338 entries, 0 to 542337
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      542338 non-null  object
#  1   book_id      542338 non-null  int64
#  2   review_id    542338 non-null  object
#  3   rating       542338 non-null  int64
#  4   review_text  542338 non-null  object
#  5   date_added   542338 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 24.8+ MB

# %%
reviews.to_csv('data/reviews_comics_cleaned.csv')

# %% [markdown]
# <b>Note - Interactions Data:</b><br>
# This dataset also included an "interactions" data file that I thought would be helpful. I loaded in the interactions data, but that actually is redundent given the reviews/books datasets I've loaded. It just shows how users have interacted with different books (i.e. if they've reviewed or not).
#
# In looking at that data, I would just drop any combinations where the user hasn't read the book, because that provides no information. That means I would only keep the reviews, which is excatly what I have in the reviews dataframe I've got.

# %%
# Compress my data output files so they're under Github 100MB limit
import gzip
import shutil

with open('data/reviews_comics_cleaned.csv', 'rb') as f_in:
    with gzip.open('data/reviews_comics_cleaned.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %%
with open('data/books_comics_cleaned.csv', 'rb') as f_in:
    with gzip.open('data/books_comics_cleaned.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
